# %%
from thinshell_analysis import *

from IPython.core.magic import register_cell_magic
import time

@register_cell_magic
def skip(line, cell):
    return

# %%
key = 'sph_fid'
sh = 'RS'
dpath = get_fpath_thinshell(key)
data = pd.read_csv(dpath, index_col=0)
cpath = get_contribspath(key) + sh + '.csv'
contribs = pd.read_csv(cpath)
fig, ax = plt.subplots()
ax.plot(data['r_{RS}'], data['rho_{RS}'])
ax.scatter(contribs['r_{RS}'], contribs['rho_{RS}'], marker='x', c='k')

# %%
cell = contribs.loc[contribs['it']==420]
print(cell)
# Out:
#      it        time       r_{RS}  ish_{RS}    v_{RS}  rho_{RS}    p_{RS}  \
# 12  420  101.453396  2768.199101     446.0  0.999969   4.13529  0.274065
#
#     ShSt_{RS}  Ton_{RS}  Tej_{RS}  Tth_{RS}   lfac_{RS}     nu_m_{RS}  \
# 12   0.105064  0.075255 -0.096784  0.172038  126.851621  9.882181e+19
#
#         Lth_{RS}       Lp_{RS}  it.1
# 12  9.659604e+27  1.178226e+28   420

# %%
cell_l = contribs.iloc[-1]
print(cell_l)
# Out:
# it           1.932000e+04
# time         4.050498e+03
# r_{RS}       6.717097e+03
# ish_{RS}     8.000000e+00
# v_{RS}       9.999727e-01
# rho_{RS}     6.907777e-01
# p_{RS}       3.504693e-02
# ShSt_{RS}    7.814444e-02
# Ton_{RS}     3.685513e-01
# Tej_{RS}     1.139036e-03
# Tth_{RS}     3.674122e-01
# lfac_{RS}    1.352144e+02
# nu_m_{RS}    2.147109e+19
# Lth_{RS}     1.679841e+28
# Lp_{RS}      3.809984e+28
# it.1         1.931000e+04
# Name: 451, dtype: float64

# %%
env = MyEnv(key)
T = np.linspace(0, 5, 2250)
# %matplotlib
nu_pks, nF_pks = get_pksnunFnu(key)
fig, (ax1, ax2) = plt.subplots(2,1)
ax1.semilogy(T, nu_pks[0]/env.nu0, c='r')
ax2.plot(T, nF_pks[0]/env.nu0F0, c='r')
# Out:
# Using matplotlib backend: tkagg
# Reading file /home/acharlet/Science/ARCO/MWN/GAMMA_MWN/results/sph_fid/thinshell_pks.csv

# %%
nu_pks[0].size
# Out:
# 2250
