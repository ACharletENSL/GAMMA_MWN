# %%
from IPython.core.magic import register_cell_magic
@register_cell_magic
def skip(line, cell):
    return

from phys_constants import *
from environment import MyEnv
from phys_functions import logslope_arr, Band_func
from peak_modeling import *
from flux_modeling import *
from obs_functions import obs_arrays
from analysis_thinshell import *
from fits_hydro import get_hydrofits_shell, replace_withfit
from fits_peaks import get_radfit_peaks
from IO import open_rundata, get_variable
import matplotlib.pyplot as plt
plt.ion()

model1 = peaks_model_R24
model2 = peaks_model_plaws
model3 = peaks_model_C25

# %% [markdown]
# ## Analytical model
# Peaks model from R24b + Band spectral shape

# %%
au, dR = 2, 1.3
g2FS, g2RS = g2_from_au(au)
T_max=5
lognu_min=-3
lognu_max=2
NT=100
Nnu=500
sl_RS=[-.5, -1.25]
sl_FS=[-.5, -1.25]
tT_RS  = np.geomspace(1, 1+T_max, NT)
nub = np.logspace(lognu_min, lognu_max, Nnu)

# %%
nu_RS, nF_RS = peaks_model_R24(tT_RS, au, dR, g2RS)
nuFnu_RS = np.zeros((NT, Nnu))
for i, tT, nup, nFp in zip(range(NT), tT_RS, nu_RS, nF_RS):
  x = nub/nup
  nuFnu_RS[i] += nFp * x * Band_func(x, *sl_RS)

# %%
nuFnu_RS = flux_model_1shock_R24(au, dR, g2RS, tT_RS, nub, sl_RS)

# %%
#for i in [0, 10, 20, 50]:
for tT in [1., 1.2, 1.4, 2.5]:
  i = np.searchsorted(tT_RS, tT)
  plt.loglog(nub, nuFnu_RS[i], label=f'{tT_RS[i]:.1f}')
plt.legend(title='$\\tilde{T}=$')

# %%
for lognu in [0, -1, -2]:
  i = np.searchsorted(np.log10(nub), lognu)
  plt.plot(tT_RS, nuFnu_RS[:,i], label=f'{lognu:.0f}')
plt.legend(title='$\\log_{10}(\\nu/\\nu_0)=$')

# %%
T_label  = '$\\tilde{T}$'
nu_label = '$\\nu/\\nu_0$'
nF_label = '$(\\nu F_\\nu)/\\nu_0F_0$'

# %%
au, dRRS, dRFS = 2, 1.3, 1.6
title_au = f"$a_u={au}$"
title_dRRS = "$\\Delta R_{\\rm RS}=" + f"{dRRS:.1f}R_0$"
title_dRFS = "$\\Delta R_{\\rm FS}=" + f"{dRFS:.1f}R_0$"
title = title_au + ', ' + title_dRRS + ', ' + title_dRFS
nuFnu_RS, nuFnu_FS = flux_model_R24(au, dRRS, dRFS)

# %%
tT = tT_RS
for lognu, ls in zip([0, -1], ['-', ':']):
  i = np.searchsorted(np.log10(nub), lognu)
  plt.plot(tT, nuFnu_RS[:,i], c='r', ls=ls)
  plt.plot(tT, nuFnu_FS[:,i], c='b', ls=ls)
  plt.plot(tT, nuFnu_RS[:,i]+nuFnu_FS[:,i], c='k', ls=ls, label=f'{lognu:.0f}')
plt.legend(title='$\\log_{10}(\\nu/\\nu_{0,\\rm RS})=$')
plt.xlabel(T_label+'$_{\\rm RS}$')
plt.ylabel(nF_label+'$_{\\rm, RS}$')
plt.title(title)
# Out:
# Text(0.5, 1.0, '$a_u=2$, $\\Delta R_{\\rm RS}=1.3R_0$, $\\Delta R_{\\rm FS}=1.6R_0$')

# %%
for T, ls in zip([1.1, 2.], ['-', ':']):
  i = np.searchsorted(tT_RS, T)
  plt.loglog(nub, nuFnu_RS[i], c='r', ls=ls)
  plt.loglog(nub, nuFnu_FS[i], c='b', ls=ls)
  plt.loglog(nub, nuFnu_RS[i]+nuFnu_FS[i], c='k', ls=ls, label=f'{tT_RS[i]:.1f}')
plt.legend(title='$\\tilde{T}_{\\rm RS}=$')
plt.xlabel(nu_label+'$_{\\rm, RS}$')
plt.ylabel(nF_label+'$_{\\rm, RS}$')
plt.title(title)
# Out:
# Text(0.5, 1.0, '$a_u=2$, $\\Delta R_{\\rm RS}=1.3R_0$, $\\Delta R_{\\rm FS}=1.6R_0$')

# %%
T_label  = '$\\tilde{T}$'
nu_label = '$\\nu_{\\rm pk}/\\nu_0$'
nF_label = '$(\\nu F_\\nu)_{\\rm pk}/\\nu_0F_0$'

# %%
def plot_output(T, model, ax, *args, **kwargs):
  nu, nF = model(T, *args)
  ax.loglog(nu, nF, **kwargs)

def create_legend_colors(ax, names, colors, **kwargs):
  dummy_col = [ax.plot([], [], c=col, ls='-')[0] for col in colors]
  legend = ax.legend(dummy_col, names, **kwargs)
  return legend

def create_legend_styles(ax, names, styles, **kwargs):
  dummy_lst = [ax.plot([], [], c='k', ls=l)[0] for l in styles]
  legend = ax.legend(dummy_lst, names, **kwargs)
  return legend

# %%
def plot_hydrofit(key):
  popt_lfac2, popt_ShSt = get_hydrofits_shell(data)

# %%
def plot_modelVSdata(nu, nF, key, title, i_s=0, logx=False):
  nu_pk, nF_pk = get_peaks_from_data(key, 'RS')
  fig = plt.figure()
  gs = fig.add_gridspec(2, 1, wspace=0)
  ax1, ax2 = gs.subplots(sharex='all')
  ax1.set_title(title)
  ax1.semilogy(T[i_s:], nu_pk[i_s:], c='k')
  ax1.semilogy(T, nu, c='r', ls='--', label='model')
  if logx: ax1.set_xscale('log')
  ax1.set_ylabel(nu_label)
  ax2.plot(T, nF_pk, c='k', label='data')
  ax2.plot(T, nF, c='r', ls='--')
  ax2.set_ylabel(nF_label)
  ax2.set_xlabel(T_label)
  fig.legend(loc='center right')

# %%
def plot_peaks_data(key, corr=False):
  env = MyEnv(key)
  nu_pk, nF_pk = get_peaks_from_data(key, 'RS')
  nu, T, env = obs_arrays(key, NT=len(nu_pk), normed=True)
  if corr:
    fig, ax = plt.subplots()
    ax.set_title('Data from run ' + key)
    ax.loglog(nu_pk, nF_pk, c='r')
    ax.set_xlabel(nu_label)
    ax.set_ylabel(nF_label)
  else:
    fig, (ax1, ax2) = plt.subplots(2,1)
    ax1.set_title('Data from run ' + key)
    ax1.semilogy(T, nu_pk, c='r')
    ax1.set_ylabel(nu_label)
    ax2.plot(T, nF_pk, c='r')
    ax2.set_ylabel(nF_label)
    ax2.set_xlabel(T_label)

# %%
def plot_data_vs_fit(key, corr=False):
  env = MyEnv(key)
  front = 'RS'
  z = 1 if (front == 'FS') else 4
  au = env.a_u
  dR = get_Rcrossing(key, z) - 1.
  T, nu_pk, nF_pk = get_peaks_from_data(key, front, withT=True)
  (m, lfac2_sph), (n, Sh_Sph) = extract_plaws(key, z)
  k, xi_sat, s = get_radfit_peaks(key, front)
  nu, nF = peaks_model_C25(T, au, dR, m, lfac2_sph, n, Sh_sph, k, xi_sat, s)
  if corr:
    fig, ax = plt.subplots()
    ax.loglog(nu_pk, nF_pk, c='k')
    ax.loglog(nu, nF, c='r', ls='--')
    ax.set_xlabel(nu_label)
    ax.set_ylabel(nF_label)
  else:
    fig, (ax, ax2) = plt.subplots(2,1)
    ax.semilogy(T, nu_pk, c='k')
    ax.semilogy(T, nu, c='r', ls='--')
    ax.set_ylabel(nu_label)
    ax2.plot(T, nF_pk, c='k')
    ax2.plot(T, nF, c='r', ls='--')
    ax2.set_ylabel(nF_label)
    ax2.set_xlabel(T_label)
  ax.set_title('Data from run ' + key)
  ax.plot([], [], c='k',label='data')
  ax.plot([], [], c='r', ls='--',label='model')
  fig.legend()

# %% [markdown]
# We test the various models for observed peak frequency and flux in the different models and compare them with data from our simulation

# %% [markdown]
# ### Data:
# observed peaks from fiducial run in spherical geometry

# %%
# %%skip
# plot_peaks_data('sph_fid', True)

# %%
# %%skip
# plot_peaks_data('sph_big', True)

# %% [markdown]
# ### Model1: Rahaman et al. 2024b
# This model assumes constant Lorentz factor of the emitting region and constant energy dissipation in the shock

# %%
# %%skip
# T = np.geomspace(1, 6, 450)
# nu, nF = model1(T, 2, 1.3)
# fig = plt.figure()
# gs = fig.add_gridspec(2, 1, wspace=0)
# ax1, ax2 = gs.subplots(sharex='all')
# ax1.set_title('Model 1: R24b')
# ax1.semilogy(T, nu_pk, c='k')
# ax1.semilogy(T, nu, c='r', ls='--', label='model')
# ax1.set_ylabel('$\\nu_{\\rm pk}/\\nu_0$')
# ax2.plot(T, nF_pk, c='k', label='data')
# ax2.plot(T, nF, c='r', ls='--')
# ax2.set_ylabel('$(\\nu F_\\nu)_{\\rm pk}/\\nu_0F_0$')
# ax2.set_xlabel('$\\tilde{T}$')
# fig.legend(loc='center right')

# %%
# %%skip
# T = np.geomspace(1, 10, 100)
# dRs = [0.2, 1, 5]
# lstyles = ['-', '-.', ':']
# fig, ax = plt.subplots()
# ax.set_xlabel('$\\nu_{\\rm pk}/\\nu_0$')
# ax.set_ylabel('$(\\nu F\\nu)_{\\rm pk}/\\nu_0F_0$')
# ax.set_title('$a_u=2$')
# legend = create_legend_styles(ax, [f'{dR:.1f}' for dR in dRs], lstyles,
#     title='$\\Delta R/R_0$')
#
# for dR, ls in zip(dRs, lstyles):
#   plot_output(T, model1, ax, 2, dR, c='r', ls=ls)

# %%
# %%skip
# T = np.geomspace(1, 5, 100)
# aus = [2, 5]
# lstyles = ['-', '-.']
# fig, ax = plt.subplots()
# ax.set_xlabel('$\\nu_{\\rm pk}/\\nu_0$')
# ax.set_ylabel('$(\\nu F\\nu)_{\\rm pk}/\\nu_0F_0$')
# ax.set_title('$\Delta R/R_0=0.5$')
# legend = create_legend_styles(ax, [f'{au:.1f}' for au in aus], lstyles,
#     title='$a_u$')
#
# for au, ls in zip(aus, lstyles):
#   plot_output(T, model1, ax, au, 0.5, c='r', ls=ls)

# %%
# %%skip
# fig, ax = plt.subplots()
# ax.loglog(nu_pk[nu_pk>0], nF_pk[nu_pk>0], c='k')
# ax.loglog(nu, nF, c='r', ls='--')

# %%
# %%skip
# # quick comparison between the simplified and original version
# def g2_from_au(au):
#   '''
#   Ratio of downstream L.F. to shock front L.F., squared
#   '''
#
#   # R24b (I1), ratio between \Gamma and \Gamma_4
#   K = np.sqrt(2) / np.sqrt(1 + au*au)
#
#   # relative LF in UR regime (Sari & Piran 95, Eq 3)
#   G34 = .5 * (1/K + K)
#
#   # plug this in R24a eqn (C5)
#   # use UR approx beta = 1 - 1/(2*Gamma**2)
#   qR = 4*G34*K
#   gRS2 = (qR - K*K)/(qR - 1)
#   return gRS2
# def peaks_model(nu_pks, au, dR):
#   '''
#   Peak flux vs peak frequency, normalized, from the collision of UR shells
#   parameters:
#     nu_pks:     normalized peak observed frequency
#       type np.ndarray, replace "np.where" by if/else if you prefer a float as input
#     au:         a_u, proper velocity contrast
#     dR:         \Delta R_f/R_0, distance crossed by the shock front, units R_0
#   '''
#
#   # downstream L.F. to shock front L.F. ratio
#   g2 = g2_from_au(au)
#
#   # break frequency
#   nu_bk = 1/(1 + g2*dR)
#
#   # model functions
#   rise = (nu_pks > nu_bk)
#   def flux_rise(nu):
#     return 1 - nu**3
#   def flux_HLE(nu):
#     nF_bk = flux_rise(nu_bk)
#     return nF_bk * (nu/nu_bk)**3
#   nF = np.where(rise, flux_rise(nu_pks), flux_HLE(nu_pks))
#
#   return nF
#
# au, dR = 2, 1.3
# T = np.geomspace(1, 6, 450)
# nu, nF = model1(T, au, dR)
# nu_2 = np.logspace(-1, 0, 450)
# nF_2 = peaks_model(nu_2, au, dR)
#
# fig, ax = plt.subplots()
# ax.loglog(nu_2, nF_2, c='r')
# ax.loglog(nu, nF, c='darkred', ls='--')

# %% [markdown]
# ### Model2: Generalization
# This model adds variability of LF and dissipation rate: $\Gamma^2\propto R^{-m}$, $L'_{\rm bol}\propto R^{-n}$. For now, m and n are not constrained by the model, but they are being determined by simulations over a range of parameter space.
#
# Reference values:
# $a_u=2$:, $m=-0.32$ and $n=0.89$
# $a_u=5$:, $m=-0.76$ and $n=0.86$

# %%
# %%skip
# T = np.geomspace(1, 6, 450)
# nu, nF = model2(T, 2, 1.3, -0.3, 0.5)
# fig = plt.figure()
# gs = fig.add_gridspec(2, 1, wspace=0)
# ax1, ax2 = gs.subplots(sharex='all')
# ax1.set_title('Model 2: generalized')
# ax1.semilogy(T, nu_pk, c='k')
# ax1.semilogy(T, nu, c='r', ls='--', label='model')
# ax1.set_ylabel('$\\nu_{\\rm pk}/\\nu_0$')
# ax2.plot(T, nF_pk, c='k', label='data')
# ax2.plot(T, nF, c='r', ls='--')
# ax2.set_ylabel('$(\\nu F_\\nu)_{\\rm pk}/\\nu_0F_0$')
# ax2.set_xlabel('$\\tilde{T}$')
# fig.legend(loc='center right')

# %%
# %%skip
# T = np.geomspace(1, 10, 500)
# dRs = [0.2, 1, 5]
# lstyles = ['-', '-.', ':']
# fig, ax = plt.subplots()
# ax.set_xlabel('$\\nu_{\\rm pk}/\\nu_0$')
# ax.set_ylabel('$(\\nu F\\nu)_{\\rm pk}/\\nu_0F_0$')
# ax.set_title('$a_u=2$')
# legend = create_legend_styles(ax, [f'{dR:.1f}' for dR in dRs], lstyles,
#     title='$\\Delta R/R_0$')
#
# for dR, ls in zip(dRs, lstyles):
#   plot_output(T, model2, ax, 2, dR, -0.32, 0.89, c='r', ls=ls)

# %%
# %%skip
# T = np.geomspace(1, 5, 1000)
# aus, ms, ns = [2, 5], [-0.32, -0.76], [0.89, 0.86]
# lstyles = ['-', '-.', ':']
# fig, ax = plt.subplots()
# ax.set_xlabel('$\\nu_{\\rm pk}/\\nu_0$')
# ax.set_ylabel('$(\\nu F\\nu)_{\\rm pk}/\\nu_0F_0$')
# ax.set_title('$\Delta R/R_0=0.5$')
# legend = create_legend_styles(ax, [f'{au:.1f}' for au in aus], lstyles,
#     title='$a_u$')
#
# for au, m, n, ls in zip(aus, ms, ns, lstyles):
#   plot_output(T, model2, ax, au, 0.5, m, n, c='r', ls=ls)

# %% [markdown]
# ### Model 3: The effective angle approximation
# Model of Charlet et al. 2025 (\S 3.4), simplified to take as little parameters as possible
# Reference values:
# $a_u=2$:, $m=-0.32$ and $n=0.89$
# $a_u=5$:, $m=-0.76$ and $n=0.86$

# %%
# %%skip
# T, nu_pk, nF_pk = get_peaks_from_data('sph_fid', 'RS', withT=True)
# m, n = -0.41, 0.9
# lfac2_sph, Sh_sph = 1.16, 0.68
# k, xi_sat = 0.148, 5
# nu, F = model3(T, 2, 1.36, m, lfac2_sph, n, Sh_sph, k, xi_sat, s=2)
# nF = nu*F
#
# plot_modelVSdata(nu, nF, 'sph_fid', '', i_s=1)
# plt.tight_layout()

# %%
# %%skip
# T = np.geomspace(1, 6, 450)
# au, dR = 2, 1.62
# m, n = -0.4, 0.95
# lfac2_sph, Sh_sph = 1.16, 0.68
# k, xi_sat = 0.145, 5
# nu, F = model3(T, 2, 10, m, lfac2_sph, n, Sh_sph, k, xi_sat, s=2)
# nF = nu*F
#
# fig, ax = plt.subplots()
# ax.loglog(nu_pk, nF_pk, c='k')
# ax.loglog(nu, nF, c='r', ls='--')

# %%
# %%skip
# dRs = np.logspace(-2, 1)
# s = 2.
# freqs = [freqs_model_C25(2, dR, m, lfac2_sph, n, Sh_sph, k, xi_sat, s)
#     for dR in dRs]
# nu_bks, nu_hfs = np.array([list(i) for i in zip(*freqs)])
# ratio = nu_bks/nu_hfs
#
# plt.loglog(dRs, nu_hfs)
# plt.xlabel('$\\Delta R/R_0$')
# plt.ylabel('$\\nu_{\\rm bk}/\\nu_{1/2}$')

# %%
# %%skip
# plot_data_vs_fit('sph_fid')

# %%
# %%skip
# plot_data_vs_fit('sph_big')

# %%
# %%skip
# key, front, z = 'sph_big', 'RS', 4
# data = open_rundata(key, z)
# data = replace_withfit(data)
# env = MyEnv(key)
# au = env.a_u
# # get Delta R/R0 from data
# dR = get_Rcrossing(key, z) - 1.
# # get the peaks
# T, nu_pk, nF_pk = get_peaks_from_data(key, front, withT=True)
# data_pk = np.hstack((nu_pk, nF_pk))
# # get the fitted parameter for hydro
# popt_lfac2, popt_ShSt = get_hydrofits_shell(data)
# lfac2_sph, m, s_lf = popt_lfac2
# Sh_sph, n, s_sh = popt_ShSt
# m, n = -m, -n
# def lfac2(x):
#   return smooth_bpl(x, lfac2_sph, -m, 0, s_lf)
# def ShSt(x):
#   return smooth_bpl(x, Sh_sph, -n, 0, s_lf)

# %%
# %%skip
# r = data.x * c_ /env.R0
# lfac2_data = (get_variable(data, 'lfac', env)/env.lfac0)**2
# ShSt_data = get_variable(data, 'ShSt', env)/(env.lfac34-1)
# plt.plot(r, lfac2_data)
# plt.plot(r, lfac2(r), c='k', ls=':')
# plt.plot(r, ShSt_data)
# plt.plot(r, ShSt(r), c='k', ls=':')
